# %%
## import dependencies 
import tensorflow as tf
import numpy as np 
import pandas as pd 
from datetime import datetime, date, time
date_form = DateFormatter("%m-%d")
import os 
import glob
import csv
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import seaborn as sns

# %%
## importing dependencies 
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS 

## define influxdb paramters
token = "A1hvR7pmPINW66Wuxbb7dpwR74TukBJIC7IuP3ADhr4xTx0Zzx-JZxzgInUUFbikMsg_bNo2TI4QnbXnUIOkDg=="
org = "ThirdYearProject"
bucket = "de75cd94d8127ada"

## connect to influxdb
client = InfluxDBClient(url="http://localhost:8086", token=token, org=org)

# %%
## query data

query_api = client.query_api()

query1_train = 'from(bucket:"MicrosoftData")\
|> range(start:  2015-01-01T00:00:00Z, stop: 2015-11-01T11:59:59Z)\
|> filter(fn: (r) => r._measurement == "Network Prediction"\
and r.Channel == "channel_1301" and r.Segment == "34")\
|> pivot(rowKey:["_time"], columnKey:["_field"], valueColumn:"_value")\
|> keep(columns: ["_time", "Q-Factor"])'

query2_train = 'from(bucket:"MicrosoftData")\
|> range(start:  2015-01-01T00:00:00Z, stop: 2015-11-01T11:59:59Z)\
|> filter(fn: (r) => r._measurement == "Network Prediction"\
and r.Channel == "channel_1302" and r.Segment == "34")\
|> pivot(rowKey:["_time"], columnKey:["_field"], valueColumn:"_value")\
|> keep(columns: ["_time", "Q-Factor"])'

query3_train = 'from(bucket:"MicrosoftData")\
|> range(start:  2015-01-01T00:00:00Z, stop: 2015-11-01T11:59:59Z)\
|> filter(fn: (r) => r._measurement == "Network Prediction"\
and r.Channel == "channel_1303" and r.Segment == "34")\
|> pivot(rowKey:["_time"], columnKey:["_field"], valueColumn:"_value")\
|> keep(columns: ["_time", "Q-Factor"])'

query4_train = 'from(bucket:"MicrosoftData")\
|> range(start:  2015-01-01T00:00:00Z, stop: 2015-11-01T11:59:59Z)\
|> filter(fn: (r) => r._measurement == "Network Prediction"\
and r.Channel == "channel_1304" and r.Segment == "34")\
|> pivot(rowKey:["_time"], columnKey:["_field"], valueColumn:"_value")\
|> keep(columns: ["_time", "Q-Factor"])'

query5_train = 'from(bucket:"MicrosoftData")\
|> range(start:  2015-01-01T00:00:00Z, stop: 2015-11-01T11:59:59Z)\
|> filter(fn: (r) => r._measurement == "Network Prediction"\
and r.Channel == "channel_1305" and r.Segment == "34")\
|> pivot(rowKey:["_time"], columnKey:["_field"], valueColumn:"_value")\
|> keep(columns: ["_time", "Q-Factor"])'

query6_train = 'from(bucket:"MicrosoftData")\
|> range(start:  2015-01-01T00:00:00Z, stop: 2015-11-01T11:59:59Z)\
|> filter(fn: (r) => r._measurement == "Network Prediction"\
and r.Channel == "channel_1306" and r.Segment == "34")\
|> pivot(rowKey:["_time"], columnKey:["_field"], valueColumn:"_value")\
|> keep(columns: ["_time", "Q-Factor"])'

query7_train = 'from(bucket:"MicrosoftData")\
|> range(start:  2015-01-01T00:00:00Z, stop: 2015-11-01T11:59:59Z)\
|> filter(fn: (r) => r._measurement == "Network Prediction"\
and r.Channel == "channel_1307" and r.Segment == "34")\
|> pivot(rowKey:["_time"], columnKey:["_field"], valueColumn:"_value")\
|> keep(columns: ["_time", "Q-Factor"])'

def dataReady(query):
    data = query_api.query_data_frame(query)
    data.set_index("_time", inplace=True)
    data.index = pd.to_datetime(data.index)
    data.drop('result', axis=1, inplace=True)
    data.drop('table', axis=1, inplace=True)
    return data

data1  = dataReady(query1_train)
data2  = dataReady(query2_train)
data3  = dataReady(query3_train)
data4  = dataReady(query4_train)
data5  = dataReady(query5_train)
data6  = dataReady(query6_train)
data7  = dataReady(query7_train)

# %%
#data1.describe().transpose()

# %%
#data2.describe().transpose()

# %%
data3.describe().transpose()
# Out:
#             count      mean       std   min    25%    50%    75%    max
# Q-Factor  12444.0  12.06559  0.605948  7.97  12.19  12.23  12.27  12.52

# %%
data4.describe().transpose()
# Out:
#             count       mean       std   min    25%    50%    75%   max
# Q-Factor  12444.0  12.323656  0.545842  9.07  12.45  12.48  12.51  12.8

# %%
data5.describe().transpose()
# Out:
#             count       mean       std   min    25%    50%    75%    max
# Q-Factor  12444.0  12.219135  0.513935  9.09  12.34  12.36  12.39  12.68

# %%
data6.describe().transpose()
# Out:
#             count       mean       std   min    25%    50%    75%    max
# Q-Factor  12444.0  12.129702  0.649276  8.13  12.28  12.32  12.35  12.63

# %%
data7.describe().transpose()
# Out:
#             count       mean       std  min    25%    50%    75%   max
# Q-Factor  12444.0  12.022303  0.567534  8.8  12.13  12.18  12.22  12.5

# %%
fig, ax = plt.subplots()
ax.scatter(data3.index, data3['Q-Factor'], s=5)
ax.set(xlabel="Date (mm-dd)", ylabel="Q-Factor")
ax.xaxis.set_major_formatter(date_form)
ax.grid(linestyle="--")
ax.set_title('Channel 1303 Segment 34')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(data4.index, data4['Q-Factor'], s=5)
ax.set(xlabel="Date (mm-dd)", ylabel="Q-Factor")
ax.xaxis.set_major_formatter(date_form)
ax.grid(linestyle="--")
ax.set_title('Channel 1304 Segment 34')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(data5.index, data5['Q-Factor'], s=5)
ax.set(xlabel="Date (mm-dd)", ylabel="Q-Factor")
ax.xaxis.set_major_formatter(date_form)
ax.grid(linestyle="--")
ax.set_title('Channel 1305 Segment 34')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(data6.index, data6['Q-Factor'], s=5)
ax.set(xlabel="Date (mm-dd)", ylabel="Q-Factor")
ax.xaxis.set_major_formatter(date_form)
ax.grid(linestyle="--")
ax.set_title('Channel 1306 Segment 34')
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(data7.index, data7['Q-Factor'], s=5)
ax.set(xlabel="Date (mm-dd)", ylabel="Q-Factor")
ax.xaxis.set_major_formatter(date_form)
ax.grid(linestyle="--")
ax.set_title('Channel 1307 Segment 34')
plt.show()

# %%
#data_train = pd.concat([data1, data2, data3, data4], axis=1)
#data_train.columns = ["Data1", "Data2", "Data3", "Data4"]
df = pd.concat([data3, data4, data5, data6, data7], axis=1)
df.columns = ["Data3", "Data4", "Data5", "Data6", "Data7"]
df.head()
# Out:
#                            Data3  Data4  Data5  Data6  Data7
# _time
# 2015-05-10 00:00:00+00:00  12.41  12.72  12.62  12.56  12.34
# 2015-05-10 00:15:00+00:00  12.40  12.71  12.64  12.53  12.33
# 2015-05-10 00:30:00+00:00  12.43  12.68  12.63  12.53  12.34
# 2015-05-10 00:45:00+00:00  12.44  12.68  12.66  12.52  12.35
# 2015-05-10 01:00:00+00:00  12.47  12.69  12.67  12.53  12.36

# %%
#for col in data_train:
    #print(data_train[col].isnull().sum())

# %%
#function to create input features
def ts_data_generator(data, window_size, batch_size, shuffle_buffer):
    ts_data = tf.data.Dataset.from_tensor_slices(data)
    ts_data = ts_data.window(window_size + 1, shift=1, drop_remainder=True)
    ts_data = ts_data.flat_map(lambda window: window.batch(window_size+1))
    ts_data = ts_data.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
    ts_data = ts_data.batch(batch_size).prefetch(1)
    return ts_data #expanding data into tensors 

## required parameters
WINDOW_SIZE = 335
BATCH_SIZE = 128
SHUFFLE_BUFFER = 12500

# %%
## converting data to numpy for better/faster processing 
time_index_data3 = np.array(data3.index)
data3_np = np.array(data3)
time_index_data4 = np.array(data4.index)
data4_np = np.array(data4)
time_index_data5 = np.array(data5.index)
data5_np = np.array(data5)
time_index_data6 = np.array(data6.index)
data6_np = np.array(data6)
time_index_data7 = np.array(data7.index)
data7_np = np.array(data7)

# %%
#splitting train into train/validation 
def splitData(data, time_index):
    n=len(data)
    train_data = data[:int(n*0.7)]
    train_time = time_index[:int(n*0.7)]
    val_data = data[int(n*0.7):int(n*0.75)]
    val_time = time_index[int(n*0.7):int(n*0.75)]
    test_data = data[int(n*0.75):]
    test_time = time_index[int(n*0.75):]
    return train_data, train_time, val_data, val_time, test_data, test_time

train_data3, train_time3, val_data3, val_time3, test_data3, test_time3 = splitData(data3_np, time_index_data3)
train_data4, train_time4, val_data4, val_time4, test_data4, test_time4 = splitData(data4_np, time_index_data4)
train_data5, train_time5, val_data5, val_time5, test_data5, test_time5 = splitData(data5_np, time_index_data5)
train_data6, train_time6, val_data6, val_time6, test_data6, test_time6 = splitData(data6_np, time_index_data6)
train_data7, train_time7, val_data7, val_time7, test_data7, test_time7 = splitData(data7_np, time_index_data7)

# %%
print(len(train_data3))
print(len(train_data4))
print(len(train_data5))
print(len(train_data6))
print(len(train_data7))
# Out:
# 8710
# 8710
# 8710
# 8710
# 8710

# %%
# generating input and output features for training and testing set 
def tensorData(train_data, val_data):
    tensor_train_data = tf.expand_dims(train_data, axis=-1)
    tensor_val_data = tf.expand_dims(val_data, axis=-1)

    tensor_train_dataset = ts_data_generator(tensor_train_data, WINDOW_SIZE, BATCH_SIZE, SHUFFLE_BUFFER)
    tensor_val_dataset = ts_data_generator(tensor_val_data, WINDOW_SIZE, BATCH_SIZE, SHUFFLE_BUFFER)
    return tensor_train_dataset, tensor_val_dataset

tensor_train_dataset3, tensor_val_dataset3 = tensorData(train_data3, val_data3)
tensor_train_dataset4, tensor_val_dataset4 = tensorData(train_data4, val_data4)
tensor_train_dataset5, tensor_val_dataset5 = tensorData(train_data5, val_data5)
tensor_train_dataset6, tensor_val_dataset6 = tensorData(train_data6, val_data6)
tensor_train_dataset7, tensor_val_dataset7 = tensorData(train_data7, val_data7)

# %%
#building model 
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu",
        input_shape=[None,1]),
    tf.keras.layers.LSTM(128, return_sequences=True),

    tf.keras.layers.LSTM(128, return_sequences=True), 
    
    tf.keras.layers.Dense(60, activation="relu"),  

    tf.keras.layers.Dense(30, activation="relu"),  

    tf.keras.layers.Dense(10, activation="relu"), 

    tf.keras.layers.Dense(1)])

model.summary()

optimiser = tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0.9)
model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=optimiser, metrics=[tf.keras.metrics.RootMeanSquaredError()])

## training model
history3 = model.fit(tensor_train_dataset3, epochs=20, validation_data=tensor_val_dataset3)
history4 = model.fit(tensor_train_dataset4, epochs=20, validation_data=tensor_val_dataset4)              
history5 = model.fit(tensor_train_dataset5, epochs=20, validation_data=tensor_val_dataset5) 
history6 = model.fit(tensor_train_dataset6, epochs=20, validation_data=tensor_val_dataset6) 
history7 = model.fit(tensor_train_dataset7, epochs=20, validation_data=tensor_val_dataset7)

combined_rmse = np.concatenate([history3.history['root_mean_squared_error'], history4.history['root_mean_squared_error'], history5.history['root_mean_squared_error'],history6.history['root_mean_squared_error'],history7.history['root_mean_squared_error']])
val_combined_rmse = np.concatenate([history3.history['val_root_mean_squared_error'], history4.history['val_root_mean_squared_error'], history5.history['val_root_mean_squared_error'],history6.history['val_root_mean_squared_error'],history7.history['val_root_mean_squared_error']])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, None, 64)          384
#
#  lstm_4 (LSTM)               (None, None, 128)         98816
#
#  lstm_5 (LSTM)               (None, None, 128)         131584
#
#  lstm_6 (LSTM)               (None, None, 128)         131584
#
#  lstm_7 (LSTM)               (None, None, 128)         131584
#
#  dense_4 (Dense)             (None, None, 60)          7740
#
#  dense_5 (Dense)             (None, None, 30)          1830
#
#  dense_6 (Dense)             (None, None, 10)          310
#
#  dense_7 (Dense)             (None, None, 1)           11
#
# =================================================================
# Total params: 503,843
# Trainable params: 503,843
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[120], line 27
#      24 model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=optimiser, metrics=[tf.keras.metrics.RootMeanSquaredError()])
#      26 ## training model
# ---> 27 history = model.fit(tensor_train_dataset3, epochs=20, validation_data=tensor_val_dataset3)
#      28 history.append(model.fit(tensor_train_dataset4, epochs=20, validation_data=tensor_val_dataset4))
#      29 history.append(model.fit(tensor_train_dataset5, epochs=20, validation_data=tensor_val_dataset5))
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:963, in Function._call(self, *args, **kwds)
#     960 try:
#     961   # This is the first call of __call__, so we have to initialize.
#     962   initializers = []
# --> 963   self._initialize(args, kwds, add_initializers_to=initializers)
#     964 finally:
#     965   # At this point we know that the initialization is complete (or less
#     966   # interestingly an exception was raised) so we no longer need a lock.
#     967   self._lock.release()
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:785, in Function._initialize(self, args, kwds, add_initializers_to)
#     782 self._lifted_initializer_graph = lifted_initializer_graph
#     783 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     784 self._concrete_stateful_fn = (
# --> 785     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     786         *args, **kwds))
#     788 def invalid_creator_scope(*unused_args, **unused_kwds):
#     789   """Disables variable creation."""
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:2983, in Function._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2981   args, kwargs = None, None
#    2982 with self._lock:
# -> 2983   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2984 return graph_function
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:3292, in Function._maybe_define_function(self, args, kwargs)
#    3288   return self._define_function_with_shape_relaxation(
#    3289       args, kwargs, flat_args, filtered_flat_args)
#    3291 self._function_cache.add_call_context(cache_key.call_context)
# -> 3292 graph_function = self._create_graph_function(args, kwargs)
#    3293 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                          graph_function)
#    3296 return graph_function, filtered_flat_args
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3125 missing_arg_names = [
#    3126     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3127 ]
#    3128 arg_names = base_arg_names + missing_arg_names
#    3129 graph_function = ConcreteFunction(
# -> 3130     func_graph_module.func_graph_from_py_func(
#    3131         self._name,
#    3132         self._python_function,
#    3133         args,
#    3134         kwargs,
#    3135         self.input_signature,
#    3136         autograph=self._autograph,
#    3137         autograph_options=self._autograph_options,
#    3138         arg_names=arg_names,
#    3139         override_flat_arg_shapes=override_flat_arg_shapes,
#    3140         capture_by_value=self._capture_by_value),
#    3141     self._function_attributes,
#    3142     function_spec=self.function_spec,
#    3143     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3144     # scope. This is not the default behavior since it gets used in some
#    3145     # places (like Keras) where the FuncGraph lives longer than the
#    3146     # ConcreteFunction.
#    3147     shared_func_graph=False)
#    3148 return graph_function
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:1161, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1158 else:
#    1159   _, original_func = tf_decorator.unwrap(python_func)
# -> 1161 func_outputs = python_func(*func_args, **func_kwargs)
#    1163 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1164 # TensorArrays and `None`s.
#    1165 func_outputs = nest.map_structure(convert, func_outputs,
#    1166                                   expand_composites=True)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:1136, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1134 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1135 try:
# -> 1136   return autograph.converted_call(
#    1137       original_func,
#    1138       args,
#    1139       kwargs,
#    1140       options=autograph.ConversionOptions(
#    1141           recursive=True,
#    1142           optional_features=autograph_options,
#    1143           user_requested=True,
#    1144       ))
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filej6w2z4tn.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:1010, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1007   run_step = tf.function(
#    1008       run_step, jit_compile=True, experimental_relax_shapes=True)
#    1009 data = next(iterator)
# -> 1010 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1011 outputs = reduce_per_replica(
#    1012     outputs, self.distribute_strategy, reduction='first')
#    1013 return outputs
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1312, in StrategyBase.run(***failed resolving arguments***)
#    1307 with self.scope():
#    1308   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1309   # applied when the caller is also in Eager mode.
#    1310   fn = autograph.tf_convert(
#    1311       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2888, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2886   kwargs = {}
#    2887 with self._container_strategy().scope():
# -> 2888   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3689, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3687 def _call_for_each_replica(self, fn, args, kwargs):
#    3688   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689     return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:1000, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     999 def run_step(data):
# -> 1000   outputs = model.train_step(data)
#    1001   # Ensure counter is updated only if `train_step` succeeds.
#    1002   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:863, in Model.train_step(self, data)
#     861 self._validate_target_and_loss(y, loss)
#     862 # Run backwards pass.
# --> 863 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     864 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:530, in OptimizerV2.minimize(self, loss, var_list, grad_loss, name, tape)
#     499 def minimize(self, loss, var_list, grad_loss=None, name=None, tape=None):
#     500   """Minimize `loss` by updating `var_list`.
#     501
#     502   This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     528
#     529   """
# --> 530   grads_and_vars = self._compute_gradients(
#     531       loss, var_list=var_list, grad_loss=grad_loss, tape=tape)
#     532   return self.apply_gradients(grads_and_vars, name=name)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:583, in OptimizerV2._compute_gradients(self, loss, var_list, grad_loss, tape)
#     581 var_list = tf.nest.flatten(var_list)
#     582 with tf.name_scope(self._name + "/gradients"):
# --> 583   grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     585 self._assert_valid_dtypes([
#     586     v for g, v in grads_and_vars
#     587     if g is not None and v.dtype != tf.resource
#     588 ])
#     590 return grads_and_vars
#
# File ~\anaconda3\envs\tf\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:464, in OptimizerV2._get_gradients(self, tape, loss, var_list, grad_loss)
#     462 def _get_gradients(self, tape, loss, var_list, grad_loss=None):
#     463   """Called in `minimize` to compute gradients from loss."""
# --> 464   grads = tape.gradient(loss, var_list, grad_loss)
#     465   return list(zip(grads, var_list))
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\backprop.py:1081, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1077 if output_gradients is not None:
#    1078   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1079                       for x in nest.flatten(output_gradients)]
# -> 1081 flat_grad = imperative_grad.imperative_grad(
#    1082     self._tape,
#    1083     flat_targets,
#    1084     flat_sources,
#    1085     output_gradients=output_gradients,
#    1086     sources_raw=flat_sources_raw,
#    1087     unconnected_gradients=unconnected_gradients)
#    1089 if not self._persistent:
#    1090   # Keep track of watched variables before setting tape to None
#    1091   self._watched_variables = self._tape.watched_variables()
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:752, in _DelayedRewriteGradientFunctions._backward.<locals>._backward_function(*args)
#     750 def _backward_function(*args):
#     751   call_op = outputs[0].op
# --> 752   return self._rewrite_forward_and_call_backward(call_op, *args)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:668, in _DelayedRewriteGradientFunctions._rewrite_forward_and_call_backward(self, op, *doutputs)
#     666 def _rewrite_forward_and_call_backward(self, op, *doutputs):
#     667   """Add outputs to the forward call and feed them to the grad function."""
# --> 668   forward_function, backwards_function = self.forward_backward(len(doutputs))
#     669   if not backwards_function.outputs:
#     670     return backwards_function.structured_outputs
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:601, in _DelayedRewriteGradientFunctions.forward_backward(self, num_doutputs)
#     599 if forward_backward is not None:
#     600   return forward_backward
# --> 601 forward, backward = self._construct_forward_backward(num_doutputs)
#     602 self._cached_function_pairs[num_doutputs] = (forward, backward)
#     603 return forward, backward
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:644, in _DelayedRewriteGradientFunctions._construct_forward_backward(self, num_doutputs)
#     641 with self._func_graph.as_default():
#     642   backwards_graph = func_graph_module.FuncGraph(
#     643       _backward_name(self._func_graph.name))
# --> 644   func_graph_module.func_graph_from_py_func(
#     645       name=backwards_graph.name,
#     646       python_func=_backprop_function,
#     647       args=[], kwargs={},
#     648       signature=signature,
#     649       func_graph=backwards_graph)
#     650   backwards_graph_captures = backwards_graph.external_captures
#     651   captures_from_forward = [
#     652       c for c in backwards_graph_captures if
#     653       not isinstance(c, ops.EagerTensor) and c.graph is self._func_graph]
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:1161, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1158 else:
#    1159   _, original_func = tf_decorator.unwrap(python_func)
# -> 1161 func_outputs = python_func(*func_args, **func_kwargs)
#    1163 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1164 # TensorArrays and `None`s.
#    1165 func_outputs = nest.map_structure(convert, func_outputs,
#    1166                                   expand_composites=True)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py:635, in _DelayedRewriteGradientFunctions._construct_forward_backward.<locals>._backprop_function(*grad_ys)
#     633 def _backprop_function(*grad_ys):
#     634   with ops.device(None):
# --> 635     return gradients_util._GradientsHelper(  # pylint: disable=protected-access
#     636         trainable_outputs,
#     637         self._func_graph.inputs,
#     638         grad_ys=grad_ys,
#     639         src_graph=self._func_graph)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gradients_util.py:679, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     674 with src_graph._original_op(op):
#     675   # pylint: enable=protected-access
#     676   if grad_fn:
#     677     # If grad_fn was found, do not use SymbolicGradient even for
#     678     # functions.
# --> 679     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     680                              lambda: grad_fn(op, *out_grads))
#     681   else:
#     682     # For function call ops, we add a 'SymbolicGradient'
#     683     # node to the graph to compute gradients.
#     684     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     685                              lambda: _SymGrad(op, out_grads))
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gradients_util.py:328, in _MaybeCompile(scope, op, func, grad_fn)
#     325     xla_compile = False
#     327 if not xla_compile:
# --> 328   return grad_fn()  # Exit early
#     330 # If the gradients are supposed to be compiled separately, we give them a
#     331 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     332 # they just inherit the existing _XlaScope name, which lets them be merged
#     333 # together with the non-gradient computation.
#     334 if xla_separate_compiled_gradients:
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gradients_util.py:680, in _GradientsHelper.<locals>.<lambda>()
#     674 with src_graph._original_op(op):
#     675   # pylint: enable=protected-access
#     676   if grad_fn:
#     677     # If grad_fn was found, do not use SymbolicGradient even for
#     678     # functions.
#     679     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 680                              lambda: grad_fn(op, *out_grads))
#     681   else:
#     682     # For function call ops, we add a 'SymbolicGradient'
#     683     # node to the graph to compute gradients.
#     684     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     685                              lambda: _SymGrad(op, out_grads))
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\while_v2.py:384, in _WhileGrad(op, *grads)
#     378 # We compute the gradient for the sub-graph between trainable ys and xs
#     379 # with non-None incoming gradients. We later pad the None's to the list of
#     380 # outputs.
#     381 ys, xs, non_none_grads = zip(*[(y, x, grad) for (y, x, grad) in zip(
#     382     body_graph.outputs, body_graph.inputs, grads) if grad is not None])
# --> 384 body_grad_graph, args = _create_grad_func(
#     385     ys, xs, non_none_grads, cond_graph, body_graph,
#     386     util.unique_grad_fn_name(body_graph.name), op, maximum_iterations,
#     387     stateful_parallelism)
#     389 if body_grad_graph.while_op_needs_rewrite:
#     390   # Modify 'op' to output the intermediate accumulators needed by the grad
#     391   # function.
#     392   # NOTE(skyewm): if there are any active sessions, this modification to `op`
#     393   # may make them unrunnable!
#     395   cond_graph.name += "_rewritten"
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\while_v2.py:686, in _create_grad_func(ys, xs, grads, cond_graph, body_graph, name, while_op, maximum_iterations, stateful_parallelism)
#     683 args = [counter, maximum_iterations, total_iters] + list(grads)
#     684 # Note: The returned function does not have `args` in the list of
#     685 # `external_captures`.
# --> 686 grad_func_graph = func_graph_module.func_graph_from_py_func(
#     687     name,
#     688     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     689     args, {},
#     690     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     691                                        maximum_iterations, while_op,
#     692                                        body_graph_inputs, body_graph_outputs),
#     693     acd_record_initial_resource_uses=stateful_parallelism)
#     695 # Update the list of outputs with tensors corresponding to the captured
#     696 # tensors. We capture 3 types of tensors when building the grad fn:
#     697 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     700 # 2. Resources, which are output as is.
#     701 # 3. Forward graph loop invariants, which are output as is.
#     702 for external_capture, internal_capture in grad_func_graph.captures:
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:1161, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1158 else:
#    1159   _, original_func = tf_decorator.unwrap(python_func)
# -> 1161 func_outputs = python_func(*func_args, **func_kwargs)
#    1163 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1164 # TensorArrays and `None`s.
#    1165 func_outputs = nest.map_structure(convert, func_outputs,
#    1166                                   expand_composites=True)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\while_v2.py:688, in _create_grad_func.<locals>.<lambda>(*args)
#     683 args = [counter, maximum_iterations, total_iters] + list(grads)
#     684 # Note: The returned function does not have `args` in the list of
#     685 # `external_captures`.
#     686 grad_func_graph = func_graph_module.func_graph_from_py_func(
#     687     name,
# --> 688     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     689     args, {},
#     690     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     691                                        maximum_iterations, while_op,
#     692                                        body_graph_inputs, body_graph_outputs),
#     693     acd_record_initial_resource_uses=stateful_parallelism)
#     695 # Update the list of outputs with tensors corresponding to the captured
#     696 # tensors. We capture 3 types of tensors when building the grad fn:
#     697 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     700 # 2. Resources, which are output as is.
#     701 # 3. Forward graph loop invariants, which are output as is.
#     702 for external_capture, internal_capture in grad_func_graph.captures:
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\while_v2.py:744, in _grad_fn(ys, xs, args, func_graph)
#     737 grad_ys = args[3:]
#     739 # Build the gradient graph. Note that this builds the gradient computation of
#     740 # func_graph in the current graph, which requires capturing tensors from
#     741 # func_graph. The captured func_graph tensors are resolved to external tensors
#     742 # after the forward While op has been rewritten in _resolve_grad_captures.
#     743 # TODO(srbs): Mark GradientsHelper as public?
# --> 744 grad_outs = gradients_util._GradientsHelper(
#     745     ys, xs, grad_ys=grad_ys, src_graph=func_graph,
#     746     unconnected_gradients="zero")
#     748 # TODO(b/118712257): Handle the case when grad_outs has None's e.g. when there
#     749 # is a tf.StopGradient in the loop body.
#     750 assert all(g is not None for g in grad_outs)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gradients_util.py:679, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     674 with src_graph._original_op(op):
#     675   # pylint: enable=protected-access
#     676   if grad_fn:
#     677     # If grad_fn was found, do not use SymbolicGradient even for
#     678     # functions.
# --> 679     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     680                              lambda: grad_fn(op, *out_grads))
#     681   else:
#     682     # For function call ops, we add a 'SymbolicGradient'
#     683     # node to the graph to compute gradients.
#     684     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     685                              lambda: _SymGrad(op, out_grads))
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gradients_util.py:328, in _MaybeCompile(scope, op, func, grad_fn)
#     325     xla_compile = False
#     327 if not xla_compile:
# --> 328   return grad_fn()  # Exit early
#     330 # If the gradients are supposed to be compiled separately, we give them a
#     331 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     332 # they just inherit the existing _XlaScope name, which lets them be merged
#     333 # together with the non-gradient computation.
#     334 if xla_separate_compiled_gradients:
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gradients_util.py:680, in _GradientsHelper.<locals>.<lambda>()
#     674 with src_graph._original_op(op):
#     675   # pylint: enable=protected-access
#     676   if grad_fn:
#     677     # If grad_fn was found, do not use SymbolicGradient even for
#     678     # functions.
#     679     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 680                              lambda: grad_fn(op, *out_grads))
#     681   else:
#     682     # For function call ops, we add a 'SymbolicGradient'
#     683     # node to the graph to compute gradients.
#     684     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     685                              lambda: _SymGrad(op, out_grads))
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\math_grad.py:1382, in _MulGrad(op, grad)
#    1379   gx = gen_math_ops.mul(grad, y)
#    1380 else:
#    1381   gx = array_ops.reshape(
# -> 1382       math_ops.reduce_sum(gen_math_ops.mul(grad, y), rx), sx)
#    1383 if skip_input_indices is not None and 1 in skip_input_indices:
#    1384   gy = None
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6588, in mul(x, y, name)
#    6586     pass  # Add nodes to the TensorFlow graph.
#    6587 # Add nodes to the TensorFlow graph.
# -> 6588 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6589       "Mul", x=x, y=y, name=name)
#    6590 _result = _outputs[:]
#    6591 if _execute.must_record_gradient():
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\op_def_library.py:740, in _apply_op_helper(op_type_name, name, **keywords)
#     735 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     736                         if arg.is_ref]
#     737 with _MaybeColocateWith(must_colocate_inputs):
#     738   # Add Op to graph
#     739   # pylint: disable=protected-access
# --> 740   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     741                              name=scope, input_types=input_types,
#     742                              attrs=attr_protos, op_def=op_def)
#     744 # `outputs` is returned as a separate return value so that the output
#     745 # tensors can the `op` per se can be decoupled so that the
#     746 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     747 # for more details.
#     748 outputs = op.outputs
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\while_v2.py:1035, in _WhileBodyGradFuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    1018 if (op_type in optimized_reduction_ops and
#    1019     not util.output_all_intermediates() and
#    1020     all(input.graph is self._forward_graph for input in inputs) and
#    (...)
#    1023     not util.graph_wrapped_for_higher_order_tape_gradients(
#    1024         self._forward_graph)):
#    1025   return self._move_op_to_forward_graph(
#    1026       op_type,
#    1027       inputs,
#    (...)
#    1032       op_def=op_def,
#    1033       compute_device=compute_device)
# -> 1035 return super(_WhileBodyGradFuncGraph, self)._create_op_internal(
#    1036     op_type,
#    1037     inputs,
#    1038     dtypes=dtypes,
#    1039     input_types=input_types,
#    1040     name=name,
#    1041     attrs=attrs,
#    1042     op_def=op_def,
#    1043     compute_device=compute_device)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:691, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     689   if ctxt is not None and hasattr(ctxt, "AddValue"):
#     690     inp = ctxt.AddValue(inp)
# --> 691   inp = self.capture(inp)
#     692   captured_inputs.append(inp)
#     693 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     695     compute_device)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:758, in FuncGraph.capture(self, tensor, name, shape)
#     748       raise errors.InaccessibleTensorError(
#     749           f"{tensor!r} is out of scope and cannot be used here. Use return "
#     750           "values, explicit Python locals or TensorFlow collections to "
#    (...)
#     755           f"The tensor {tensor!r} cannot be accessed from {self}, because "
#     756           f"it was defined in {tensor.graph}, which is out of scope.")
#     757     inner_graph = inner_graph.outer_graph
# --> 758   return self._capture_helper(tensor, name)
#     759 return tensor
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\while_v2.py:1216, in _WhileBodyGradFuncGraph._capture_helper(self, tensor, name)
#    1213   # Capture in the cond graph as well so the forward cond and body inputs
#    1214   # match.
#    1215   with self._forward_cond_graph.as_default():
# -> 1216     self._forward_cond_graph.capture(tensor_list)
#    1218 # Capture the accumulator tensor list in the gradient graph directly from
#    1219 # the forward graph -- we'll later modify this to capture the final list
#    1220 # output by the forward While op instead.
#    1221 captured_accumulator = super(_WhileBodyGradFuncGraph, self)._capture_helper(
#    1222     accumulator, name)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:758, in FuncGraph.capture(self, tensor, name, shape)
#     748       raise errors.InaccessibleTensorError(
#     749           f"{tensor!r} is out of scope and cannot be used here. Use return "
#     750           "values, explicit Python locals or TensorFlow collections to "
#    (...)
#     755           f"The tensor {tensor!r} cannot be accessed from {self}, because "
#     756           f"it was defined in {tensor.graph}, which is out of scope.")
#     757     inner_graph = inner_graph.outer_graph
# --> 758   return self._capture_helper(tensor, name)
#     759 return tensor
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:764, in FuncGraph._capture_helper(self, tensor, name, shape)
#     762 capture = self._captures.get(id(tensor))
#     763 if capture is None:
# --> 764   placeholder = _create_substitute_placeholder(
#     765       tensor, name=name, dtype=tensor.dtype, shape=shape)
#     766   # Record the composite device as an attribute to the placeholder.
#     767   # This attribute would be propogated into the arg_attr of the FunctionDef.
#     768   # Currently, a packed eager tensor is always placed on a CompositeDevice.
#     769   if isinstance(tensor, ops.EagerTensor) and tensor.is_packed:
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:1305, in _create_substitute_placeholder(value, name, dtype, shape)
#    1303   shape = value.shape
#    1304 with ops.control_dependencies(None):
# -> 1305   placeholder = graph_placeholder(
#    1306       dtype=dtype or value.dtype, shape=shape, name=name)
#    1307 handle_data_util.copy_handle_data(value, placeholder)
#    1308 return placeholder
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\graph_only_ops.py:34, in graph_placeholder(dtype, shape, name)
#      32 g = ops.get_default_graph()
#      33 attrs = {"dtype": dtype_value, "shape": shape}
# ---> 34 op = g._create_op_internal(  # pylint: disable=protected-access
#      35     "Placeholder", [], [dtype], input_types=[],
#      36     attrs=attrs, name=name)
#      37 result, = op.outputs
#      38 if op_callbacks.should_invoke_op_callbacks():
#      39   # TODO(b/147670703): Once the special-op creation code paths
#      40   # are unified. Remove this `if` block.
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\func_graph.py:693, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     691   inp = self.capture(inp)
#     692   captured_inputs.append(inp)
# --> 693 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     695     compute_device)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:3776, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3773 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3774 # Session.run call cannot occur between creating and mutating the op.
#    3775 with self._mutation_lock():
# -> 3776   ret = Operation(
#    3777       node_def,
#    3778       self,
#    3779       inputs=inputs,
#    3780       output_types=dtypes,
#    3781       control_inputs=control_inputs,
#    3782       input_types=input_types,
#    3783       original_op=self._default_original_op,
#    3784       op_def=op_def)
#    3785   self._create_op_helper(ret, compute_device=compute_device)
#    3786 return ret
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:2171, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2169   if op_def is None:
#    2170     op_def = self._graph._get_op_def(node_def.op)
# -> 2171   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2172                             control_input_ops, op_def)
#    2173   name = compat.as_str(node_def.name)
#    2175 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1983, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1981 inputs = _reconstruct_sequence_inputs(op_def, inputs, node_def.attr)
#    1982 # pylint: disable=protected-access
# -> 1983 op_desc = pywrap_tf_session.TF_NewOperation(graph._c_graph,
#    1984                                             compat.as_str(node_def.op),
#    1985                                             compat.as_str(node_def.name))
#    1986 if node_def.device:
#    1987   pywrap_tf_session.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:

# %%
## losses of the model
#plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
#plt.title('model loss')
#plt.ylabel('loss')
#plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
#plt.show()

# %%
#error loss of the model
plt.plot(combined_rmse)
plt.plot(val_combined_rmse)
plt.title('Root Mean Squared Error (RMSE)')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend(['train', 'validate'], loc='upper right')
plt.grid(linestyle="--")
plt.show()

# %%
## making a prediction
def model_forecast(model, data, window_size, batch_size):
    ds = tf.data.Dataset.from_tensor_slices(data)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(batch_size).prefetch(1)
    forecast = model.predict(ds)#returns learned label for each object in array 
    #dimensions:(no. windows, window size, no. features)
    return forecast

#adding dimension to test_data so it matches 3 dimensional forecast
forecast = model_forecast(model, data3_np[...,np.newaxis], WINDOW_SIZE, BATCH_SIZE)

# %%
predicted_values = forecast[int(n*0.75)-WINDOW_SIZE:-1,-1,0]#batch size (: all) time slice (-1 last one) features (only one, so first one)

# %%
error = tf.keras.metrics.RootMeanSquaredError()
error.update_state(test_data3, predicted_values)
rmse = error.result().numpy()
print(rmse)

# %%
fig, ax = plt.subplots()
ax.scatter(test_time3, test_data3, s=9)
ax.scatter(test_time3, predicted_values, s=9)
ax.set(xlabel="Date (mm-dd)", ylabel="Q-Factor")
ax.xaxis.set_major_formatter(date_form)
ax.grid(linestyle="--")
ax.set_title('Comparing Prediction and Test Q-Factor Values')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 date_form = DateFormatter("%m-%d")
#       2 fig, ax = plt.subplots()
#       3 ax.scatter(test_time3, test_data3, s=9)
#
# NameError: name 'DateFormatter' is not defined

# %%
# comparison graph 
plt.plot(test_data1)
plt.plot(predicted_values)
plt.title('Prediction vs Test')
plt.ylabel('Q-Factor')
plt.xlabel('Time')
plt.legend(['test', 'predictions'], loc='upper left')
plt.show()
